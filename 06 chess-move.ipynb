# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("200k.csv", low_memory = False)
df.head()
# Out:
#    Index  Index.1          Black  BlackElo  BlackRatingDiff        Date  ECO  \
# 0      0      124  albertoPlasta       906             13.0  2019.04.30  B15
# 1      1      494   Luckystriker      1296             28.0  2019.04.30  C50
# 2      2      552   Verascardoso      1761            -13.0  2019.04.30  C41
# 3      3      588    Stockfish94      2404              8.0  2019.04.30  B06
# 4      4      725    deneme12376      1595            -10.0  2019.04.30  B32
#
#                Event                                 Opening Result Round  \
# 0   Rated Blitz game                       Caro-Kann Defense    0-1     -
# 1   Rated Blitz game                            Italian Game    0-1     -
# 2   Rated Rapid game                     Philidor Defense #2    1-0     -
# 3  Rated Bullet game                          Modern Defense    0-1     -
# 4   Rated Blitz game  Sicilian Defense: Loewenthal Variation    1-0     -
#
# ...
